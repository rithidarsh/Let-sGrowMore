# %% [markdown]
# <a href="https://colab.research.google.com/github/rithidarsh/Let-sGrowMore/blob/main/LGMVIP_Task1_PencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

def pencil_sketch(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    inverted_image = cv2.bitwise_not(gray_image)

    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)

    sketch = cv2.divide(gray_image, blurred_image, scale=256.0)

    return sketch

input_image = cv2.imread("/content/drive/MyDrive/Let'sGrowMore/dog.jpg")

sketch_image = pencil_sketch(input_image)

cv2_imshow(input_image)
cv2_imshow(sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
# <PIL.Image.Image image mode=L size=400x300>
